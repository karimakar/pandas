# %%
import pandas as pd

# %%
# %%time
data = pd.read_csv('file_csv.csv')
data
# Out:
# Wall time: 610 ms
#        Unnamed: 0  movieId                               title  \
# 0               0        1                    Toy Story (1995)
# 1               1        2                      Jumanji (1995)
# 2               2        3             Grumpier Old Men (1995)
# 3               3        4            Waiting to Exhale (1995)
# 4               4        5  Father of the Bride Part II (1995)
# ...           ...      ...                                 ...
# 27273       27273   131254        Kein Bund für's Leben (2007)
# 27274       27274   131256       Feuer, Eis & Dosenbier (2002)
# 27275       27275   131258                  The Pirates (2014)
# 27276       27276   131260                 Rentun Ruusu (2001)
# 27277       27277   131262                    Innocence (2014)
#
#                                             genres
# 0      Adventure|Animation|Children|Comedy|Fantasy
# 1                       Adventure|Children|Fantasy
# ...

# %%
# convert csv to hdf
# Out:
# UsageError: Line magic function `%%time` not found.

# %%
# %%time
data.to_hdf('nasa.h5',key='data')
# Out:
# Wall time: 325 ms

# %%
# %%time 
df=pd.read_hdf('nasa.h5')
df
# Out:
# Wall time: 125 ms
#        Unnamed: 0  movieId                               title  \
# 0               0        1                    Toy Story (1995)
# 1               1        2                      Jumanji (1995)
# 2               2        3             Grumpier Old Men (1995)
# 3               3        4            Waiting to Exhale (1995)
# 4               4        5  Father of the Bride Part II (1995)
# ...           ...      ...                                 ...
# 27273       27273   131254        Kein Bund für's Leben (2007)
# 27274       27274   131256       Feuer, Eis & Dosenbier (2002)
# 27275       27275   131258                  The Pirates (2014)
# 27276       27276   131260                 Rentun Ruusu (2001)
# 27277       27277   131262                    Innocence (2014)
#
#                                             genres
# 0      Adventure|Animation|Children|Comedy|Fantasy
# 1                       Adventure|Children|Fantasy
# ...

# %%
# %%time
data = pd.ExcelFile('file_excel.xlsx')
# Out:
# Wall time: 31 s

# %%
# %%time
df =pd.read_excel(data,"Sheet1")
# Out:
# Wall time: 9.52 s

# %%
# %%time
df
# Out:
#        Unnamed: 0  movieId                               title  \
# 0               0        1                    Toy Story (1995)
# 1               1        2                      Jumanji (1995)
# 2               2        3             Grumpier Old Men (1995)
# 3               3        4            Waiting to Exhale (1995)
# 4               4        5  Father of the Bride Part II (1995)
# ...           ...      ...                                 ...
# 27273       27273   131254        Kein Bund für's Leben (2007)
# 27274       27274   131256       Feuer, Eis & Dosenbier (2002)
# 27275       27275   131258                  The Pirates (2014)
# 27276       27276   131260                 Rentun Ruusu (2001)
# 27277       27277   131262                    Innocence (2014)
#
#                                             genres
# 0      Adventure|Animation|Children|Comedy|Fantasy
# 1                       Adventure|Children|Fantasy
# 2                                   Comedy|Romance
# ...
