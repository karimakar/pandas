# %% [markdown]
# # Data Loading, Storage, and File Formats

# %% [markdown]
# ## HTML_Web Scraping

# %%
import pandas as pd

# %%
data = pd.read_html('https://en.wikipedia.org/wiki/Demographics_of_Morocco')

# %%
data[0]
# Out:
#                   Demographics of Morocco  \
# 0   Population pyramid of Morocco in 2020
# 1                              Population
# 2                             Growth rate
# 3                              Birth rate
# 4                              Death rate
# 5                         Life expectancy
# 6                                  • male
# 7                                • female
# 8                          Fertility rate
# 9                   Infant mortality rate
# 10                     Net migration rate
# 11                          Age structure
# 12                             0–14 years
# 13                            65 and over
# 14                              Sex ratio
# 15                                  Total
# 16                               At birth
# 17                               Under 15
# 18                            65 and over
# 19                            Nationality
# 20                            Nationality
# ...

# %%
data1 = pd.read_html('https://en.wikipedia.org/wiki/Demographics_of_Morocco',
                     match=None)

# %%
data1

# %%
df = pd.read_html('https://en.wikipedia.org/wiki/Demographics_of_India')

# %%
len(df)
# Out:
# 38

# %%
# Population distribution by states/union territories (2011)
df = pd.read_html('https://en.wikipedia.org/wiki/Demographics_of_India',
                  match='Population distribution by states/union territories')

# %%
df[0].head()
# Out:
#   Rank        State/UT  Population[54]  Percent (%)       Male    Female  \
# 0    1   Uttar Pradesh       199812341        16.50  104480510  95331831
# 1    2     Maharashtra       112374333         9.28   58243056  54131277
# 2    3           Bihar       104099452         8.60   54278157  49821295
# 3    4     West Bengal        91276115         7.54   46809027  44467088
# 4    5  Madhya Pradesh        72626809         6.00   37612306  35014503
#
#   Difference between male and female  Sex ratio  Rural[55]  Urban[55]  \
# 0                            9148679        930  155111022   44470455
# 1                            4111779        929   61545441   50827531
# 2                            4456862        918   92075028   11729609
# 3                            2341939        950   62213676   29134060
# 4                            2597803        931   52537899   20059666
#
#    Area[56] (km2)  Density (per km2)
# 0          240928                828
# ...

# %%
type(df[0])
# Out:
# pandas.core.frame.DataFrame

# %%
df[0]['State/UT']
# Out:
# 0                        Uttar Pradesh
# 1                          Maharashtra
# 2                                Bihar
# 3                          West Bengal
# 4                       Madhya Pradesh
# 5                           Tamil Nadu
# 6                            Rajasthan
# 7                            Karnataka
# 8                              Gujarat
# 9                       Andhra Pradesh
# 10                              Odisha
# 11                           Telangana
# 12                              Kerala
# 13                           Jharkhand
# 14                               Assam
# 15                              Punjab
# 16                        Chhattisgarh
# 17                             Haryana
# 18                          Delhi (UT)
# 19                   Jammu and Kashmir
# 20                         Uttarakhand
# 21                    Himachal Pradesh
# 22                             Tripura
# 23                           Meghalaya
# ...

# %%
df[0].columns
# Out:
# Index(['Rank', 'State/UT', 'Population[54]', 'Percent (%)', 'Male', 'Female',
#        'Difference between male and female', 'Sex ratio', 'Rural[55]',
#        'Urban[55]', 'Area[56] (km2)', 'Density (per km2)'],
#       dtype='object')

# %%
df[0]['Population[54]']
# Out:
# 0      199812341
# 1      112374333
# 2      104099452
# 3       91276115
# 4       72626809
# 5       72147030
# 6       68548437
# 7       61095297
# 8       60439692
# 9       49386799
# 10      41974218
# 11      35193978
# 12      33406061
# 13      32988134
# 14      31205576
# 15      27743338
# 16      25545198
# 17      25351462
# 18      16787941
# 19      12541302
# 20      10086292
# 21       6864602
# 22       3673917
# 23       2966889
# 24       2855794
# 25       1978502
# 26       1458545
# 27       1383727
# 28       1247953
# 29       1097206
# 30       1055450
# 31        610577
# 32        380581
# 33        343709
# 34        243247
# 35         64473
# 36    1210854977
# Name: Population[54], dtype: int64

# %%
df1=pd.DataFrame({"State/UT'":State/UI,
                 "Population":Population})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-dcfb5225e933> in <module>
# ----> 1 df1=pd.DataFrame({"State/UT'":State/UI,
#       2                  "Population":Population})
#
# NameError: name 'State' is not defined

# %%
df1=df[0][['State/UT','Population[54]']]

# %%
df1
# Out:
#                             State/UT  Population[54]
# 0                      Uttar Pradesh       199812341
# 1                        Maharashtra       112374333
# 2                              Bihar       104099452
# 3                        West Bengal        91276115
# 4                     Madhya Pradesh        72626809
# 5                         Tamil Nadu        72147030
# 6                          Rajasthan        68548437
# 7                          Karnataka        61095297
# 8                            Gujarat        60439692
# 9                     Andhra Pradesh        49386799
# 10                            Odisha        41974218
# 11                         Telangana        35193978
# 12                            Kerala        33406061
# 13                         Jharkhand        32988134
# 14                             Assam        31205576
# 15                            Punjab        27743338
# 16                      Chhattisgarh        25545198
# ...

# %%
# drop function pandas
df1.drop(df1.tail(1).index)
# Out:
#                             State/UT  Population[54]
# 0                      Uttar Pradesh       199812341
# 1                        Maharashtra       112374333
# 2                              Bihar       104099452
# 3                        West Bengal        91276115
# 4                     Madhya Pradesh        72626809
# 5                         Tamil Nadu        72147030
# 6                          Rajasthan        68548437
# 7                          Karnataka        61095297
# 8                            Gujarat        60439692
# 9                     Andhra Pradesh        49386799
# 10                            Odisha        41974218
# 11                         Telangana        35193978
# 12                            Kerala        33406061
# 13                         Jharkhand        32988134
# 14                             Assam        31205576
# 15                            Punjab        27743338
# 16                      Chhattisgarh        25545198
# ...

# %%
df1.tail(1)
# Out:
#          State/UT  Population[54]
# 36  Total (India)      1210854977

# %%
df1
# Out:
#                             State/UT  Population[54]
# 0                      Uttar Pradesh       199812341
# 1                        Maharashtra       112374333
# 2                              Bihar       104099452
# 3                        West Bengal        91276115
# 4                     Madhya Pradesh        72626809
# 5                         Tamil Nadu        72147030
# 6                          Rajasthan        68548437
# 7                          Karnataka        61095297
# 8                            Gujarat        60439692
# 9                     Andhra Pradesh        49386799
# 10                            Odisha        41974218
# 11                         Telangana        35193978
# 12                            Kerala        33406061
# 13                         Jharkhand        32988134
# 14                             Assam        31205576
# 15                            Punjab        27743338
# 16                      Chhattisgarh        25545198
# ...

# %%
import matplotlib.pyplot as plt

# %%
df1.plot(x='State/UT',y='Population[54]',kind='barh',figsize=(20,15))
# Out:
# <AxesSubplot:ylabel='State/UT'>
